# %% [markdown]
# # Lab 1: Deep Neural Network (DNN)

# %% [markdown]
# ## 1.1 Refresh: build a Single Layer Perceptron
# Let's build a single layer perceptron composed by one dense layer.<br>
# <img src="https://drive.google.com/uc?id=1cvJa9WfOier2NQIJGHpqDNGn-RlczU1x" width="500px"><br>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf


# Define the number of inputs and outputs
n_input_nodes = 2
n_output_nodes = 2

# First define the model 
model = Sequential() # model lets us define a linear stack of network layers.

# define our single fully connected network layer
dense_layer = Dense(n_output_nodes, activation='sigmoid',kernel_initializer="Ones",bias_initializer="Ones")

# Add the dense layer to the model
model.add(dense_layer)

# %% [markdown]
# ## 1.2 refresh: build a Multilayer perceptron
# Let's build a multilayer perceptron; MLPs are fully connected, each node in one layer connects with a certain weight to every node in the following layer.
#
# <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2020/02/ANN-Graph.gif" width="400px"><br>
#
# Try to build one composed by two hidden dense layer with ReLU activation and one dense output layer(units=1) with sigmoid activation.

# %%
import numpy as np
# Generate dummy data
train_data = np.random.random((1000, 100))
train_labels = np.random.randint(2, size=(1000, 1))
test_data = np.random.random((100, 100))
test_labels = np.random.randint(2, size=(100, 1))

# Build your first model by creating a Sequential object and then adding 3 Dense layers:
units = 32
# Create a Sequential
model = Sequential()
# Add a Dense layer with 32 neurons, with relu as activation function and input dimension equal to the number of features
model.add(Dense(units, activation='relu',kernel_initializer="random_normal",bias_initializer="zeros", input_dim=100))
# Add a Dense layer with 32 neurons, with relu as activation function
model.add(Dense(units, activation='relu',kernel_initializer="random_normal",bias_initializer="zeros"))
# To produce the output Add a Dense layer with 1 neurons, with sigmoid as activation function
model.add(Dense(1, activation='sigmoid',kernel_initializer="random_normal",bias_initializer="zeros"))

# %%
# Compile the model
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])


# Train the model, iterating on the data in batches of 32 samples
# The fit function output is a History object. The history.history attribute is a record of
# training loss values and metrics values at successive epochs, as well as validation loss values 
# and validation metrics values 
history = model.fit(train_data, train_labels, epochs=100, batch_size=32)
_, train_acc = model.evaluate(train_data, train_labels, verbose=1)
_, test_acc = model.evaluate(test_data, test_labels, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 1ms/step - loss: 0.6937 - accuracy: 0.4810
# Epoch 2/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6935 - accuracy: 0.4800
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6932 - accuracy: 0.5210
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.4950
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6926 - accuracy: 0.5190
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6924 - accuracy: 0.5200
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6921 - accuracy: 0.5340
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6896 - accuracy: 0.5440
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6898 - accuracy: 0.5360
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6883 - accuracy: 0.5500
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6860 - accuracy: 0.5680
# Epoch 12/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6832 - accuracy: 0.5680
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6793 - accuracy: 0.5930
# Epoch 14/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6755 - accuracy: 0.5800
# Epoch 15/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6735 - accuracy: 0.5830
# Epoch 16/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6695 - accuracy: 0.6050
# Epoch 17/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6648 - accuracy: 0.6140
# Epoch 18/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6634 - accuracy: 0.6190
# Epoch 19/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6579 - accuracy: 0.6190
# Epoch 20/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6556 - accuracy: 0.6230
# Epoch 21/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6518 - accuracy: 0.6350
# Epoch 22/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6475 - accuracy: 0.6300
# Epoch 23/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6381 - accuracy: 0.6440
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6384 - accuracy: 0.6510
# Epoch 25/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6320 - accuracy: 0.6450
# Epoch 26/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6359 - accuracy: 0.6530
# Epoch 27/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6203 - accuracy: 0.6570
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6267 - accuracy: 0.6570
# Epoch 29/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6150 - accuracy: 0.6690
# Epoch 30/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6122 - accuracy: 0.6610
# Epoch 31/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6016 - accuracy: 0.6750
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5994 - accuracy: 0.6870
# Epoch 33/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5912 - accuracy: 0.7030
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5805 - accuracy: 0.6930
# Epoch 35/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5796 - accuracy: 0.7050
# Epoch 36/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5693 - accuracy: 0.7070
# Epoch 37/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5613 - accuracy: 0.7240
# Epoch 38/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5528 - accuracy: 0.7320
# Epoch 39/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5401 - accuracy: 0.7470
# Epoch 40/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5413 - accuracy: 0.7420
# Epoch 41/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5188 - accuracy: 0.7560
# Epoch 42/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5192 - accuracy: 0.7540
# Epoch 43/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5071 - accuracy: 0.7590
# Epoch 44/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4865 - accuracy: 0.7800
# Epoch 45/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4987 - accuracy: 0.7880
# Epoch 46/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4739 - accuracy: 0.7800
# Epoch 47/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4693 - accuracy: 0.7890
# Epoch 48/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4516 - accuracy: 0.8040
# Epoch 49/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4527 - accuracy: 0.7980
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4353 - accuracy: 0.8100
# Epoch 51/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4314 - accuracy: 0.8090
# Epoch 52/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4190 - accuracy: 0.8280
# Epoch 53/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4101 - accuracy: 0.8270
# Epoch 54/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3983 - accuracy: 0.8300
# Epoch 55/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3943 - accuracy: 0.8390
# Epoch 56/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3768 - accuracy: 0.8540
# Epoch 57/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3604 - accuracy: 0.8560
# Epoch 58/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3567 - accuracy: 0.8620
# Epoch 59/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3582 - accuracy: 0.8630
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3449 - accuracy: 0.8560
# Epoch 61/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3416 - accuracy: 0.8620
# Epoch 62/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3073 - accuracy: 0.8880
# Epoch 63/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2942 - accuracy: 0.9080
# Epoch 64/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3215 - accuracy: 0.8720
# Epoch 65/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2856 - accuracy: 0.9020
# Epoch 66/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2963 - accuracy: 0.8920
# Epoch 67/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2742 - accuracy: 0.9080
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2688 - accuracy: 0.9030
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2617 - accuracy: 0.8950
# Epoch 70/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2475 - accuracy: 0.9180
# Epoch 71/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2404 - accuracy: 0.9170
# Epoch 72/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2362 - accuracy: 0.9210
# Epoch 73/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2250 - accuracy: 0.9230
# Epoch 74/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2243 - accuracy: 0.9240
# Epoch 75/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2233 - accuracy: 0.9220
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2038 - accuracy: 0.9360
# Epoch 77/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2036 - accuracy: 0.9370
# Epoch 78/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2022 - accuracy: 0.9260
# Epoch 79/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1883 - accuracy: 0.9370
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1787 - accuracy: 0.9420
# Epoch 81/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1872 - accuracy: 0.9460
# Epoch 82/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1861 - accuracy: 0.9350
# Epoch 83/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1495 - accuracy: 0.9660
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1778 - accuracy: 0.9420
# Epoch 85/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1346 - accuracy: 0.9670
# Epoch 86/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1684 - accuracy: 0.9440
# Epoch 87/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1344 - accuracy: 0.9650
# Epoch 88/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1483 - accuracy: 0.9540
# Epoch 89/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1259 - accuracy: 0.9660
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1282 - accuracy: 0.9580
# Epoch 91/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1397 - accuracy: 0.9510
# Epoch 92/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1192 - accuracy: 0.9660
# Epoch 93/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1077 - accuracy: 0.9700
# Epoch 94/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1346 - accuracy: 0.9620
# Epoch 95/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1240 - accuracy: 0.9560
# Epoch 96/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0938 - accuracy: 0.9790
# Epoch 97/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1011 - accuracy: 0.9760
# Epoch 98/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0957 - accuracy: 0.9730
# Epoch 99/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0923 - accuracy: 0.9800
# Epoch 100/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1063 - accuracy: 0.9700
# 32/32 [==============================] - 0s 925us/step - loss: 0.0496 - accuracy: 0.9930
# 4/4 [==============================] - 0s 1ms/step - loss: 1.9625 - accuracy: 0.4700
# Train: 0.993, Test: 0.470

# %% [markdown]
# # 1.3 Build a Deep Neural Network
# In this section we will:
# *  1.2.1 Import the dataset
# *  1.2.2 Build a model
# *  1.2.3 Train the model
# *  1.2.4 Evaluate the model

# %% [markdown]
# ## 1.3.1 Import the Dataset
# Fashion-MNIST is a dataset of Zalando’s article images consisting of a training set of 60,000 examples and a test set of 10,000 examples. <br>
# Each example is a 28×28 grayscale image, associated with a label from 10 classes.<br>
# <img src="https://res.cloudinary.com/practicaldev/image/fetch/s--s6xGmaZX--/c_imagga_scale,f_auto,fl_progressive,h_900,q_auto,w_1600/https://raw.githubusercontent.com/zalandoresearch/fashion-mnist/master/doc/img/fashion-mnist-sprite.png" width="600px"><br>

# %%
from sklearn.model_selection import train_test_split
mnist_fashion = tf.keras.datasets.fashion_mnist

(x_learn, y_learn),(x_test, y_test) = mnist_fashion.load_data()
x_learn, x_test = x_learn / 255.0, x_test / 255.0 # normalization 
x_train, x_val, y_train, y_val = train_test_split(x_learn, y_learn, test_size=0.3, random_state=42) # split learn in train,val
num_classes = 10 # Fashion-MNIST classes

print(x_train.shape, x_val.shape, x_test.shape)
# Out:
# (42000, 28, 28) (18000, 28, 28) (10000, 28, 28)

# %% [markdown]
# #### Plot some sample from the training set

# %%
import matplotlib.pyplot as plt
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(6,6))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ## 1.3.2 Build a Model
#
# <img src="https://drive.google.com/uc?id=1siIVKXLL7_YsecqlCQqw_ZI35LhR8XbI" width="400px"><br>
#
# A Deep Neural Network is a neural network composed by many layers and consequently it has a deeper structure. The number of layers in the network depends on different factors: for example on the data available, on the complexity of the problem, on the computational power and so on.
# The value produced as output by a neuron is determined by the input the neuron receives and by the activation function. There exists different choices for the activation function. One of the most used is Relu but it depends on the data and on the network architecture.
# <br><br>
# <img src="https://miro.medium.com/max/1400/1*LiBZo_FcnKWqoU7M3GRKbA.png" width="400px"><br>

# %% [markdown]
# #### Build a model with this structure: Flatten+Dense(ReLU)+Dense(ReLU)+Dense(ReLU)+Dense(ReLU)+Dense(softmax)

# %%
from tensorflow.keras.layers import Flatten
# https://keras.io/layers/core/
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function
model.add(Dense(512, activation='relu',kernel_initializer="random_normal",bias_initializer="zeros", input_dim=(28*28)))
# Add a Dense layer with 256 neurons, with relu as activation function
model.add(Dense(256, activation='relu'))
# Add a Dense layer with 128 neurons, with relu as activation function
model.add(Dense(128, activation='relu'))
# Add a Dense layer with 64 neurons, with relu as activation function
model.add(Dense(64, activation='relu'))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# When we are building a model there are many design choises that we must operate: the choice of a Loss Function, the Metrics and the Optimizer.<br>
#
# **Loss functions** are used to compare the network's predicted output  with the real output, in each pass of the backpropagations algorithm<br>
# Common loss functions are: mean-squared error, cross-entropy, and so on...<br><br>
# **Metrics** are used to evaluate a model; common metrics are precision, recall, accuracy, auc,..<br>
#
# The **Optimizer** determines the update rules of the weights. The performance and update speed may heavily vary from optimizer to optimizer; in choosing an optimizer what's important to consider is the network depth, the type of layers and the type of data.<br>
# The gif below give an idea on how different Optimizers work.<br>
#
# <img src="https://user-images.githubusercontent.com/11681225/49325458-fc785480-f585-11e8-8d2a-9012d6024c6e.gif" width="460px">

# %% [markdown]
# #### Configures the model for training

# %%
# Optimizers    https://www.tensorflow.org/api_docs/python/tf/keras/optimizers
from tensorflow.keras.optimizers import Adam, SGD, Adadelta, Adagrad, Adamax, Nadam, RMSprop

adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
sgd = SGD(learning_rate=0.001, momentum=0.0, decay=0.0, nesterov=False)
adad = Adadelta(learning_rate=1.0,rho=0.95,epsilon=None,decay=0.0)
adag = Adagrad(learning_rate=0.01,epsilon=None,decay=0.0)
adamax = Adamax(learning_rate=0.002,beta_1=0.9,beta_2=0.999,epsilon=None,decay=0.0)
nadam = Nadam(learning_rate=0.002,beta_1=0.9,beta_2=0.999,epsilon=None,schedule_decay=0.004)
rms = RMSprop(learning_rate=0.001,rho=0.9,epsilon=None,decay=0.0)

# Losses    https://keras.io/losses/
loss = ['sparse_categorical_crossentropy','mean_squared_error','mean_absolute_error',
        'categorical_crossentropy','categorical_hinge']

# Metrics    https://www.tensorflow.org/api_docs/python/tf/metrics
metrics = ['accuracy','precision','recall']

# %%
# Compile the model you created before using 
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
print(y_train.shape, x_train.shape)
# Out:
# (42000,) (42000, 28, 28)

# %% [markdown]
# ## 1.3.3 Train the model
# The batch size is a number of samples processed before the model is updated.<br>
# The number of epochs is the number of complete passes through the training dataset.

# %%
batch_size = 32
epochs = 15
# fit your model and save the returned value as "history". 
# Use both the train and validation set 
# Set both properly the batch size value and the epochs value

history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_val, y_val))
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/15
# 1313/1313 [==============================] - 6s 4ms/step - loss: 0.0677 - accuracy: 0.9772 - val_loss: 0.6733 - val_accuracy: 0.8962
# Epoch 2/15
# 1313/1313 [==============================] - 6s 4ms/step - loss: 0.0544 - accuracy: 0.9798 - val_loss: 0.7282 - val_accuracy: 0.8935
# Epoch 3/15
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0610 - accuracy: 0.9781 - val_loss: 0.7015 - val_accuracy: 0.8921
# Epoch 4/15
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0564 - accuracy: 0.9790 - val_loss: 0.7096 - val_accuracy: 0.8928
# Epoch 5/15
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0543 - accuracy: 0.9801 - val_loss: 0.7572 - val_accuracy: 0.8952
# Epoch 6/15
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0569 - accuracy: 0.9802 - val_loss: 0.6783 - val_accuracy: 0.8978
# Epoch 7/15
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0544 - accuracy: 0.9810 - val_loss: 0.7589 - val_accuracy: 0.8948
# Epoch 8/15
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0556 - accuracy: 0.9808 - val_loss: 0.7183 - val_accuracy: 0.8949
# Epoch 9/15
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0601 - accuracy: 0.9790 - val_loss: 0.6552 - val_accuracy: 0.8933
# Epoch 10/15
# 1313/1313 [==============================] - 6s 4ms/step - loss: 0.0584 - accuracy: 0.9802 - val_loss: 0.7504 - val_accuracy: 0.8972
# Epoch 11/15
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0488 - accuracy: 0.9820 - val_loss: 0.8087 - val_accuracy: 0.8957
# Epoch 12/15
# 1313/1313 [==============================] - 6s 4ms/step - loss: 0.0598 - accuracy: 0.9797 - val_loss: 0.7151 - val_accuracy: 0.8919
# Epoch 13/15
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0492 - accuracy: 0.9816 - val_loss: 0.6960 - val_accuracy: 0.9009
# Epoch 14/15
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.0470 - accuracy: 0.9830 - val_loss: 0.9253 - val_accuracy: 0.8892
# Epoch 15/15
# 1313/1313 [==============================] - 6s 4ms/step - loss: 0.0512 - accuracy: 0.9820 - val_loss: 0.7587 - val_accuracy: 0.8914
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0475 - accuracy: 0.9821
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9155 - accuracy: 0.8864
# Train: 0.982, Test: 0.886

# %% [markdown]
# #### Training history visualization

# %%
def plot_history(history):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()

# %%
plot_history(history)

# %% [markdown]
# **What could you notice in the loss graph training the model over large number of epochs?**

# %% [markdown]
# I see that for a large number of epochs the model becomes overfitted to the training set, and the loss graph shows that the validation set performs worse.

# %% [markdown]
# ## 1.3.4 Evaluate the model

# %%
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.1067 - accuracy: 0.9575
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5225 - accuracy: 0.8831
# Train: 0.957, Test: 0.883

# %% [markdown]
# **Try to play with these parameters (loss and optimizers) in order to see how this choice affects the accuracy. What do you expect? which is faster?**

# %% [markdown]
# # 1.4 Dealing with overfitting
# Given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.<br>
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether).<br>
# How to improve generalization of our model on unseen data?<br>
# In this section we will:
# * 1.3.1 Add weight regularization
# * 1.3.2 Dropout
# * 1.3.3 Early stopping

# %% [markdown]
# ## 1.4.1 Add weight regularization
# A common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular".<br>
# This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights.<br> This cost comes in two flavors:
# * L1 regularization
# * L2 regularization
#
# In tf.keras, weight regularization is added by passing weight regularizer instances to layers as keyword arguments.

# %%
from  tensorflow.keras import regularizers
# Build the model
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer
model.add(Dense(512, activation='relu',kernel_initializer="random_normal",bias_initializer="zeros", input_dim=(28*28), kernel_regularizer=regularizers.l2(0.001)))
# Add a Dense layer with 256 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer 
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# Add a Dense layer with 128 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer 
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# Add a Dense layer with 64 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(num_classes, activation='softmax'))

# Compile the model you just created using 
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
          
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# fit your model and save the returned value as "history". 
# Use both the train and validation set 
# Set both properly the batch size value and the epochs value
batch_size = 128
epochs = 10
          
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_val, y_val))

# Call the plot_history function to plot the obtained results
plot_history(history)
          
# Evaluate
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/10
# 329/329 [==============================] - 2s 6ms/step - loss: 1.3774 - accuracy: 0.7979 - val_loss: 0.9269 - val_accuracy: 0.8494
# Epoch 2/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.8245 - accuracy: 0.8452 - val_loss: 0.7627 - val_accuracy: 0.8409
# Epoch 3/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.6717 - accuracy: 0.8559 - val_loss: 0.6401 - val_accuracy: 0.8552
# Epoch 4/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.5963 - accuracy: 0.8621 - val_loss: 0.6359 - val_accuracy: 0.8368
# Epoch 5/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.5460 - accuracy: 0.8668 - val_loss: 0.5520 - val_accuracy: 0.8615
# Epoch 6/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.5201 - accuracy: 0.8693 - val_loss: 0.5896 - val_accuracy: 0.8436
# Epoch 7/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.4972 - accuracy: 0.8719 - val_loss: 0.5144 - val_accuracy: 0.8685
# Epoch 8/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.4776 - accuracy: 0.8764 - val_loss: 0.4998 - val_accuracy: 0.8677
# Epoch 9/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.4601 - accuracy: 0.8805 - val_loss: 0.5077 - val_accuracy: 0.8660
# Epoch 10/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.4503 - accuracy: 0.8812 - val_loss: 0.4931 - val_accuracy: 0.8662
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.4514 - accuracy: 0.8790
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5278 - accuracy: 0.8511
# Train: 0.879, Test: 0.851

# %% [markdown]
# ## 1.4.2 Dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks.<br>
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training.<br>
# <img src="https://drive.google.com/uc?id=1PcGnn9cdM5JQk2nxRHAFPZAtBj1fNMvk" width="600px"><br>
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5; at test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.

# %%
from tensorflow.keras.layers import Dropout
# Build the model
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function
model.add(Dense(512, activation='relu',kernel_initializer="random_normal",bias_initializer="zeros", input_dim=(28*28)))
# Add a Dropout layer with 0.3 drop probability
model.add(Dropout(0.3))
# Add a Dense layer with 256 neurons, with relu as activation function
model.add(Dense(256, activation='relu'))
# Add a Dropout layer with 0.3 drop probability
model.add(Dropout(0.3))
# Add a Dense layer with 128 neurons, with relu as activation function
model.add(Dense(128, activation='relu'))
# Add a Dropout layer with 0.3 drop probability
model.add(Dropout(0.3))
# Add a Dense layer with 64 neurons, with relu as activation function
model.add(Dense(64, activation='relu'))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(num_classes, activation='softmax'))

# Compile the model you just created using 
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


# fit your model and save the returned value as "history". 
# Use both the train and validation set 
# Set both properly the batch size value and the epochs value
batch_size = 128
epochs = 10

history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_val, y_val))

# Call the plot_history function to plot the obtained results
plot_history(history)

# Evaluate
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/10
# 329/329 [==============================] - 3s 7ms/step - loss: 0.7148 - accuracy: 0.7417 - val_loss: 0.4401 - val_accuracy: 0.8386
# Epoch 2/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.4649 - accuracy: 0.8324 - val_loss: 0.3916 - val_accuracy: 0.8589
# Epoch 3/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.4229 - accuracy: 0.8465 - val_loss: 0.3774 - val_accuracy: 0.8632
# Epoch 4/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.3931 - accuracy: 0.8580 - val_loss: 0.3525 - val_accuracy: 0.8710
# Epoch 5/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.3755 - accuracy: 0.8646 - val_loss: 0.3701 - val_accuracy: 0.8645
# Epoch 6/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.3619 - accuracy: 0.8680 - val_loss: 0.3380 - val_accuracy: 0.8756
# Epoch 7/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.3596 - accuracy: 0.8684 - val_loss: 0.3325 - val_accuracy: 0.8793
# Epoch 8/10
# 329/329 [==============================] - 2s 7ms/step - loss: 0.3377 - accuracy: 0.8756 - val_loss: 0.3284 - val_accuracy: 0.8779
# Epoch 9/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.3314 - accuracy: 0.8782 - val_loss: 0.3237 - val_accuracy: 0.8777
# Epoch 10/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.3204 - accuracy: 0.8831 - val_loss: 0.3271 - val_accuracy: 0.8814
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2704 - accuracy: 0.8991
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3557 - accuracy: 0.8711
# Train: 0.899, Test: 0.871

# %% [markdown]
# ## 1.4.3 Early stopping
# Validation can be used to detect when overfitting starts during supervised training of a neural network; training is then stopped before convergence to avoid the overfitting.<br>
#
# <img src="https://drive.google.com/uc?id=1prBt0w2oWIviRDjOSRKP2TglDGUr-EGZ" width="400px"><br><br>

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os
# early stopping https://keras.io/callbacks/
es_callback = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# Create checkpoint callback that will save the best model observed during training for later use
checkpoint_path = "output/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = ModelCheckpoint(checkpoint_path,monitor='val_loss',save_weights_only=True,verbose=1)

# %%
# Build the model
model = Sequential()
model.add(Flatten())

# Add a Dense layer with 512 neurons, with relu as activation function
model.add(Dense(512, activation='relu',kernel_initializer="random_normal",bias_initializer="zeros", input_dim=(28*28)))
# Add a Dense layer with 256 neurons, with relu as activation function
model.add(Dense(256, activation='relu'))
# Add a Dense layer with 128 neurons, with relu as activation function
model.add(Dense(128, activation='relu'))
# Add a Dense layer with 64 neurons, with relu as activation function
model.add(Dense(64, activation='relu'))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(num_classes, activation='softmax'))

# Compile the model you just created using 
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# fit your model and save the returned value as "history". 
# Use both the train and validation set 
# Set both properly the batch size value and the epochs value
# Be careful to also set properly the callbacks parameter list
batch_size =32
epochs = 30

history = model.fit(x_train, y_train, epochs=epochs, 
                    batch_size=batch_size, validation_data=(x_val, y_val),
                    callbacks=[es_callback, cp_callback])

# Call the plot_history function to plot the obtained results
plot_history(history)

# Evaluate
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/30
# 1313/1313 [==============================] - ETA: 0s - loss: 0.5210 - accuracy: 0.8122
# Epoch 1: saving model to output\cp.ckpt
# 1313/1313 [==============================] - 6s 4ms/step - loss: 0.5210 - accuracy: 0.8122 - val_loss: 0.4611 - val_accuracy: 0.8338
# Epoch 2/30
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.3849 - accuracy: 0.8575
# Epoch 2: saving model to output\cp.ckpt
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.3848 - accuracy: 0.8575 - val_loss: 0.3909 - val_accuracy: 0.8615
# Epoch 3/30
# 1313/1313 [==============================] - ETA: 0s - loss: 0.3457 - accuracy: 0.8707
# Epoch 3: saving model to output\cp.ckpt
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.3457 - accuracy: 0.8707 - val_loss: 0.3380 - val_accuracy: 0.8774
# Epoch 4/30
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.3176 - accuracy: 0.8816
# Epoch 4: saving model to output\cp.ckpt
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.3176 - accuracy: 0.8816 - val_loss: 0.3406 - val_accuracy: 0.8795
# Epoch 5/30
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.2994 - accuracy: 0.8882
# Epoch 5: saving model to output\cp.ckpt
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2995 - accuracy: 0.8881 - val_loss: 0.3582 - val_accuracy: 0.8676
# Epoch 6/30
# 1305/1313 [============================>.] - ETA: 0s - loss: 0.2832 - accuracy: 0.8947
# Epoch 6: saving model to output\cp.ckpt
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2833 - accuracy: 0.8947 - val_loss: 0.3671 - val_accuracy: 0.8687
# Epoch 7/30
# 1297/1313 [============================>.] - ETA: 0s - loss: 0.2693 - accuracy: 0.9005
# Epoch 7: saving model to output\cp.ckpt
# 1313/1313 [==============================] - 6s 4ms/step - loss: 0.2698 - accuracy: 0.9002 - val_loss: 0.3605 - val_accuracy: 0.8718
# Epoch 8/30
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.2631 - accuracy: 0.9019
# Epoch 8: saving model to output\cp.ckpt
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2631 - accuracy: 0.9019 - val_loss: 0.3696 - val_accuracy: 0.8761
# Epoch 8: early stopping
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.2779 - accuracy: 0.8980
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4010 - accuracy: 0.8639
# Train: 0.898, Test: 0.864

# %% [markdown]
# #### Load weights
# The saved weights can then be loaded and evaluated any time by calling the load_weights() function.

# %%
# This may generate warnings related to saving the state of the optimizer.
# These warnings (and similar warnings throughout this notebook)
# are in place to discourage outdated usage, and can be ignored.
# link https://www.tensorflow.org/tutorials/keras/save_and_restore_models

checkpoint_path = "output/cp.ckpt"

model.load_weights(checkpoint_path)

_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2095 - accuracy: 0.9197
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3639 - accuracy: 0.8770
# Train: 0.920, Test: 0.877
